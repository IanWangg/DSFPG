# %% [markdown]
# <a href="https://colab.research.google.com/github/IanWangg/DSFPG/blob/master/TD3_walk_backward.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/gdrive')

# %cd gdrive/My Drive/Workplace

# !pip install -e ./pybullet-gym

import sys
sys.path.append('./pybullet-gym')
sys.path.append('./pybullet')
import pybulletgym
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Workplace

# %%
import copy
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Implementation of Twin Delayed Deep Deterministic Policy Gradients (TD3)
# Paper: https://arxiv.org/abs/1802.09477

class ReplayBuffer(object):
    def __init__(self, state_dim, action_dim, max_size=int(1e6)):
        self.max_size = max_size
        self.ptr = 0
        self.size = 0

        self.start_ptr = 0
        self.start_size = 0

        self.state = np.zeros((max_size, state_dim))
        self.action = np.zeros((max_size, action_dim))
        self.next_state = np.zeros((max_size, state_dim))
        self.reward = np.zeros((max_size, 1))
        self.not_done = np.zeros((max_size, 1))

        self.start_state = np.zeros((max_size, state_dim))

        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    def add(self, state, action, next_state, reward, done):
        self.state[self.ptr] = state
        self.action[self.ptr] = action
        self.next_state[self.ptr] = next_state
        self.reward[self.ptr] = reward
        self.not_done[self.ptr] = 1. - done

        self.ptr = (self.ptr + 1) % self.max_size
        self.size = min(self.size + 1, self.max_size)

    def sample(self, batch_size):
        ind = np.random.randint(self.size, size=batch_size)

        return (
            torch.FloatTensor(self.state[ind]).to(self.device),
            torch.FloatTensor(self.action[ind]).to(self.device),
            torch.FloatTensor(self.next_state[ind]).to(self.device),
            torch.FloatTensor(self.reward[ind]).to(self.device),
            torch.FloatTensor(self.not_done[ind]).to(self.device)
        )


class Actor(nn.Module):
	def __init__(self, state_dim, action_dim, max_action):
		super(Actor, self).__init__()

		self.l1 = nn.Linear(state_dim, 256)
		self.l2 = nn.Linear(256, 256)
		self.l3 = nn.Linear(256, action_dim)
		
		self.max_action = max_action
		

	def forward(self, state):
		a = F.relu(self.l1(state))
		a = F.relu(self.l2(a))
		return self.max_action * torch.tanh(self.l3(a))


class Critic(nn.Module):
	def __init__(self, state_dim, action_dim):
		super(Critic, self).__init__()

		# Q1 architecture
		self.l1 = nn.Linear(state_dim + action_dim, 256)
		self.l2 = nn.Linear(256, 256)
		self.l3 = nn.Linear(256, 1)

		# Q2 architecture
		self.l4 = nn.Linear(state_dim + action_dim, 256)
		self.l5 = nn.Linear(256, 256)
		self.l6 = nn.Linear(256, 1)


	def forward(self, state, action):
		sa = torch.cat([state, action], 1)

		q1 = F.relu(self.l1(sa))
		q1 = F.relu(self.l2(q1))
		q1 = self.l3(q1)

		q2 = F.relu(self.l4(sa))
		q2 = F.relu(self.l5(q2))
		q2 = self.l6(q2)
		return q1, q2


	def Q1(self, state, action):
		sa = torch.cat([state, action], 1)

		q1 = F.relu(self.l1(sa))
		q1 = F.relu(self.l2(q1))
		q1 = self.l3(q1)
		return q1


class TD3(object):
	def __init__(
		self,
		state_dim,
		action_dim,
		max_action,
		discount=0.99,
		tau=0.005,
		policy_noise=0.2,
		noise_clip=0.5,
		policy_freq=2
	):

		self.actor = Actor(state_dim, action_dim, max_action).to(device)
		self.actor_target = copy.deepcopy(self.actor)
		self.actor_optimizer = torch.optim.Adam(self.actor.parameters(), lr=3e-4)

		self.critic = Critic(state_dim, action_dim).to(device)
		self.critic_target = copy.deepcopy(self.critic)
		self.critic_optimizer = torch.optim.Adam(self.critic.parameters(), lr=3e-4)

		self.max_action = max_action
		self.discount = discount
		self.tau = tau
		self.policy_noise = policy_noise
		self.noise_clip = noise_clip
		self.policy_freq = policy_freq

		self.total_it = 0


	def select_action(self, state):
		state = torch.FloatTensor(state.reshape(1, -1)).to(device)
		return self.actor(state).cpu().data.numpy().flatten()


	def train(self, replay_buffer, batch_size=256):
		self.total_it += 1

		# Sample replay buffer 
		state, action, next_state, reward, not_done = replay_buffer.sample(batch_size)

		with torch.no_grad():
			# Select action according to policy and add clipped noise
			noise = (
				torch.randn_like(action) * self.policy_noise
			).clamp(-self.noise_clip, self.noise_clip)
			
			next_action = (
				self.actor_target(next_state) + noise
			).clamp(-self.max_action, self.max_action)

			# Compute the target Q value
			target_Q1, target_Q2 = self.critic_target(next_state, next_action)
			target_Q = torch.min(target_Q1, target_Q2)
			target_Q = reward + not_done * self.discount * target_Q

		# Get current Q estimates
		current_Q1, current_Q2 = self.critic(state, action)

		# Compute critic loss
		critic_loss = F.mse_loss(current_Q1, target_Q) + F.mse_loss(current_Q2, target_Q)

		# Optimize the critic
		self.critic_optimizer.zero_grad()
		critic_loss.backward()
		self.critic_optimizer.step()

		# Delayed policy updates
		if self.total_it % self.policy_freq == 0:

			# Compute actor losse
			actor_loss = -self.critic.Q1(state, self.actor(state)).mean()
			
			# Optimize the actor 
			self.actor_optimizer.zero_grad()
			actor_loss.backward()
			self.actor_optimizer.step()

			# Update the frozen target models
			for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
				target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

			for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
				target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)


	def save(self, filename):
		torch.save(self.critic.state_dict(), filename + "_critic")
		torch.save(self.critic_optimizer.state_dict(), filename + "_critic_optimizer")
		
		torch.save(self.actor.state_dict(), filename + "_actor")
		torch.save(self.actor_optimizer.state_dict(), filename + "_actor_optimizer")


	def load(self, filename):
		self.critic.load_state_dict(torch.load(filename + "_critic"))
		self.critic_optimizer.load_state_dict(torch.load(filename + "_critic_optimizer"))
		self.critic_target = copy.deepcopy(self.critic)

		self.actor.load_state_dict(torch.load(filename + "_actor"))
		self.actor_optimizer.load_state_dict(torch.load(filename + "_actor_optimizer"))
		self.actor_target = copy.deepcopy(self.actor)

# %% [markdown]
# # Train / Evaluate the agent

# %%
from tqdm import trange
import gym
import pybulletgym

def eval_policy(policy, env_name, seed, eval_episodes=10):
    eval_env = gym.make(env_name)
    eval_env.seed(seed + 100)

    avg_reward = 0.
    for _ in range(eval_episodes):
        state, done = eval_env.reset(), False
        while not done:
            action = policy.select_action(np.array(state))
            state, reward, done, _ = eval_env.step(action)
            avg_reward += reward

    avg_reward /= eval_episodes

    print("---------------------------------------")
    print(f"Evaluation over {eval_episodes} episodes: {avg_reward:.3f}")
    print("---------------------------------------")
    return avg_reward

def train_agent(
    agent_func,
    env_name,
    max_steps=int(1e6),
    max_step_before_learning=10000,
):
    env = gym.make(env_name)
    state_dim = env.observation_space.shape[0]
    action_dim = env.action_space.shape[0]
    max_action = float(env.action_space.high[0])

    replay_buffer = ReplayBuffer(state_dim, action_dim)
    policy = agent_func(state_dim, action_dim, max_action)
    evaluations = [eval_policy(policy, env_name, 0)] # 0 is the seed

    state, done = env.reset(), False
    episode_reward = 0
    episode_timesteps = 0
    episode_num = 0

    for t in range(int(max_steps)):
        
        episode_timesteps += 1

        # Select action randomly or according to policy
        if t < max_step_before_learning:
            action = env.action_space.sample()
        else:
            action = (
                policy.select_action(np.array(state))
                + np.random.normal(0, max_action * 0.1, size=action_dim)
            ).clip(-max_action, max_action)

        # Perform action
        next_state, reward, done, _ = env.step(action) 
        done_bool = float(done) if episode_timesteps < env._max_episode_steps else 0

        # Store data in replay buffer
        replay_buffer.add(state, action, next_state, reward, done_bool)

        state = next_state
        episode_reward += reward

        # Train agent after collecting sufficient data
        if t >= max_step_before_learning:
            policy.train(replay_buffer, 256)

        if done: 
            # +1 to account for 0 indexing. +0 on ep_timesteps since it will increment +1 even if done=True
            print(f"Total T: {t+1} Episode Num: {episode_num+1} Episode T: {episode_timesteps} Reward: {episode_reward:.3f}")
            # Reset environment
            state, done = env.reset(), False
            episode_reward = 0
            episode_timesteps = 0
            episode_num += 1 

        # Evaluate episode
        if (t + 1) % 1000 == 0:
            evaluations.append(eval_policy(policy, env_name, 0))
    
    return evaluations

# %%
eval = train_agent(TD3, 'HopperMuJoCoEnv-v0')
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# WalkerBase::__init__
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 4.733
# ---------------------------------------
# Total T: 3 Episode Num: 1 Episode T: 3 Reward: 1.912
# Total T: 6 Episode Num: 2 Episode T: 3 Reward: 2.012
# Total T: 9 Episode Num: 3 Episode T: 3 Reward: 1.373
# Total T: 15 Episode Num: 4 Episode T: 6 Reward: 5.352
# Total T: 19 Episode Num: 5 Episode T: 4 Reward: 1.781
# Total T: 22 Episode Num: 6 Episode T: 3 Reward: 2.056
# Total T: 26 Episode Num: 7 Episode T: 4 Reward: 2.712
# Total T: 30 Episode Num: 8 Episode T: 4 Reward: 3.715
# Total T: 33 Episode Num: 9 Episode T: 3 Reward: 0.163
# Total T: 36 Episode Num: 10 Episode T: 3 Reward: 1.548
# Total T: 40 Episode Num: 11 Episode T: 4 Reward: 2.646
# Total T: 42 Episode Num: 12 Episode T: 2 Reward: 1.343
# Total T: 48 Episode Num: 13 Episode T: 6 Reward: 3.488
# Total T: 54 Episode Num: 14 Episode T: 6 Reward: 3.184
# Total T: 61 Episode Num: 15 Episode T: 7 Reward: 4.350
# Total T: 66 Episode Num: 16 Episode T: 5 Reward: 3.750
# Total T: 72 Episode Num: 17 Episode T: 6 Reward: 4.164
# Total T: 74 Episode Num: 18 Episode T: 2 Reward: 1.667
# Total T: 79 Episode Num: 19 Episode T: 5 Reward: 2.960
# Total T: 81 Episode Num: 20 Episode T: 2 Reward: 0.157
# Total T: 87 Episode Num: 21 Episode T: 6 Reward: 3.164
# Total T: 94 Episode Num: 22 Episode T: 7 Reward: 5.295
# Total T: 98 Episode Num: 23 Episode T: 4 Reward: 2.358
# Total T: 103 Episode Num: 24 Episode T: 5 Reward: 3.404
# Total T: 109 Episode Num: 25 Episode T: 6 Reward: 5.201
# Total T: 114 Episode Num: 26 Episode T: 5 Reward: 3.262
# Total T: 119 Episode Num: 27 Episode T: 5 Reward: 1.470
# Total T: 136 Episode Num: 28 Episode T: 17 Reward: 16.475
# Total T: 141 Episode Num: 29 Episode T: 5 Reward: 6.905
# Total T: 147 Episode Num: 30 Episode T: 6 Reward: 4.495
# Total T: 151 Episode Num: 31 Episode T: 4 Reward: 2.096
# Total T: 156 Episode Num: 32 Episode T: 5 Reward: 2.757
# Total T: 159 Episode Num: 33 Episode T: 3 Reward: 2.021
# Total T: 162 Episode Num: 34 Episode T: 3 Reward: 1.728
# Total T: 166 Episode Num: 35 Episode T: 4 Reward: 3.602
# Total T: 180 Episode Num: 36 Episode T: 14 Reward: 9.032
# Total T: 186 Episode Num: 37 Episode T: 6 Reward: 5.200
# Total T: 194 Episode Num: 38 Episode T: 8 Reward: 8.461
# Total T: 199 Episode Num: 39 Episode T: 5 Reward: 2.575
# Total T: 204 Episode Num: 40 Episode T: 5 Reward: 5.382
# Total T: 207 Episode Num: 41 Episode T: 3 Reward: 0.990
# Total T: 210 Episode Num: 42 Episode T: 3 Reward: 1.979
# Total T: 215 Episode Num: 43 Episode T: 5 Reward: 4.780
# Total T: 220 Episode Num: 44 Episode T: 5 Reward: 3.635
# Total T: 226 Episode Num: 45 Episode T: 6 Reward: 4.342
# Total T: 228 Episode Num: 46 Episode T: 2 Reward: 1.534
# Total T: 231 Episode Num: 47 Episode T: 3 Reward: -1.788
# Total T: 234 Episode Num: 48 Episode T: 3 Reward: 1.771
# Total T: 240 Episode Num: 49 Episode T: 6 Reward: 5.270
# Total T: 246 Episode Num: 50 Episode T: 6 Reward: 4.823
# Total T: 251 Episode Num: 51 Episode T: 5 Reward: 4.531
# Total T: 255 Episode Num: 52 Episode T: 4 Reward: 2.456
# Total T: 267 Episode Num: 53 Episode T: 12 Reward: 15.254
# Total T: 270 Episode Num: 54 Episode T: 3 Reward: 2.288
# Total T: 275 Episode Num: 55 Episode T: 5 Reward: 4.281
# Total T: 278 Episode Num: 56 Episode T: 3 Reward: 1.148
# Total T: 284 Episode Num: 57 Episode T: 6 Reward: 4.069
# Total T: 288 Episode Num: 58 Episode T: 4 Reward: 1.660
# Total T: 291 Episode Num: 59 Episode T: 3 Reward: 1.903
# Total T: 295 Episode Num: 60 Episode T: 4 Reward: 3.344
# Total T: 302 Episode Num: 61 Episode T: 7 Reward: 5.070
# Total T: 313 Episode Num: 62 Episode T: 11 Reward: 12.727
# Total T: 319 Episode Num: 63 Episode T: 6 Reward: 1.875
# Total T: 327 Episode Num: 64 Episode T: 8 Reward: 5.545
# Total T: 331 Episode Num: 65 Episode T: 4 Reward: 3.324
# Total T: 334 Episode Num: 66 Episode T: 3 Reward: 2.222
# Total T: 345 Episode Num: 67 Episode T: 11 Reward: 7.891
# Total T: 352 Episode Num: 68 Episode T: 7 Reward: 5.622
# Total T: 357 Episode Num: 69 Episode T: 5 Reward: 5.146
# Total T: 364 Episode Num: 70 Episode T: 7 Reward: 5.032
# Total T: 366 Episode Num: 71 Episode T: 2 Reward: 1.081
# Total T: 370 Episode Num: 72 Episode T: 4 Reward: 2.111
# Total T: 373 Episode Num: 73 Episode T: 3 Reward: 1.666
# Total T: 378 Episode Num: 74 Episode T: 5 Reward: 3.833
# Total T: 383 Episode Num: 75 Episode T: 5 Reward: 2.261
# Total T: 393 Episode Num: 76 Episode T: 10 Reward: 9.324
# Total T: 396 Episode Num: 77 Episode T: 3 Reward: 2.357
# Total T: 400 Episode Num: 78 Episode T: 4 Reward: 3.041
# Total T: 405 Episode Num: 79 Episode T: 5 Reward: 3.730
# Total T: 411 Episode Num: 80 Episode T: 6 Reward: 3.813
# Total T: 417 Episode Num: 81 Episode T: 6 Reward: 5.500
# Total T: 421 Episode Num: 82 Episode T: 4 Reward: 2.986
# Total T: 429 Episode Num: 83 Episode T: 8 Reward: 7.113
# Total T: 434 Episode Num: 84 Episode T: 5 Reward: 3.498
# Total T: 438 Episode Num: 85 Episode T: 4 Reward: 2.844
# Total T: 443 Episode Num: 86 Episode T: 5 Reward: 2.990
# Total T: 448 Episode Num: 87 Episode T: 5 Reward: 4.774
# Total T: 453 Episode Num: 88 Episode T: 5 Reward: 4.677
# Total T: 462 Episode Num: 89 Episode T: 9 Reward: 8.790
# Total T: 466 Episode Num: 90 Episode T: 4 Reward: 4.019
# Total T: 469 Episode Num: 91 Episode T: 3 Reward: 2.043
# Total T: 472 Episode Num: 92 Episode T: 3 Reward: 0.813
# Total T: 477 Episode Num: 93 Episode T: 5 Reward: 4.720
# Total T: 481 Episode Num: 94 Episode T: 4 Reward: 3.565
# Total T: 484 Episode Num: 95 Episode T: 3 Reward: 1.811
# Total T: 488 Episode Num: 96 Episode T: 4 Reward: 3.250
# Total T: 490 Episode Num: 97 Episode T: 2 Reward: 1.913
# Total T: 495 Episode Num: 98 Episode T: 5 Reward: 3.322
# Total T: 499 Episode Num: 99 Episode T: 4 Reward: 2.446
# Total T: 505 Episode Num: 100 Episode T: 6 Reward: 4.041
# Total T: 508 Episode Num: 101 Episode T: 3 Reward: 1.750
# Total T: 513 Episode Num: 102 Episode T: 5 Reward: 4.225
# Total T: 516 Episode Num: 103 Episode T: 3 Reward: 1.794
# Total T: 522 Episode Num: 104 Episode T: 6 Reward: 4.879
# Total T: 525 Episode Num: 105 Episode T: 3 Reward: 2.207
# Total T: 533 Episode Num: 106 Episode T: 8 Reward: 5.326
# Total T: 537 Episode Num: 107 Episode T: 4 Reward: 2.933
# Total T: 540 Episode Num: 108 Episode T: 3 Reward: 2.233
# Total T: 545 Episode Num: 109 Episode T: 5 Reward: 3.724
# Total T: 548 Episode Num: 110 Episode T: 3 Reward: 2.060
# Total T: 551 Episode Num: 111 Episode T: 3 Reward: 4.749
# Total T: 559 Episode Num: 112 Episode T: 8 Reward: 11.935
# Total T: 562 Episode Num: 113 Episode T: 3 Reward: 2.318
# Total T: 569 Episode Num: 114 Episode T: 7 Reward: 4.688
# Total T: 576 Episode Num: 115 Episode T: 7 Reward: 5.640
# Total T: 580 Episode Num: 116 Episode T: 4 Reward: 3.039
# Total T: 582 Episode Num: 117 Episode T: 2 Reward: 0.830
# Total T: 587 Episode Num: 118 Episode T: 5 Reward: 4.648
# Total T: 598 Episode Num: 119 Episode T: 11 Reward: 7.315
# Total T: 601 Episode Num: 120 Episode T: 3 Reward: 3.119
# Total T: 606 Episode Num: 121 Episode T: 5 Reward: 5.153
# Total T: 609 Episode Num: 122 Episode T: 3 Reward: -0.366
# Total T: 616 Episode Num: 123 Episode T: 7 Reward: 4.384
# Total T: 620 Episode Num: 124 Episode T: 4 Reward: 3.014
# Total T: 631 Episode Num: 125 Episode T: 11 Reward: 7.170
# Total T: 639 Episode Num: 126 Episode T: 8 Reward: 6.562
# Total T: 646 Episode Num: 127 Episode T: 7 Reward: 3.529
# Total T: 652 Episode Num: 128 Episode T: 6 Reward: 4.906
# Total T: 656 Episode Num: 129 Episode T: 4 Reward: 3.187
# Total T: 658 Episode Num: 130 Episode T: 2 Reward: 1.622
# Total T: 664 Episode Num: 131 Episode T: 6 Reward: 3.933
# Total T: 667 Episode Num: 132 Episode T: 3 Reward: 1.940
# Total T: 674 Episode Num: 133 Episode T: 7 Reward: 4.167
# Total T: 678 Episode Num: 134 Episode T: 4 Reward: 4.319
# Total T: 681 Episode Num: 135 Episode T: 3 Reward: 1.763
# Total T: 684 Episode Num: 136 Episode T: 3 Reward: 1.569
# Total T: 688 Episode Num: 137 Episode T: 4 Reward: 2.004
# Total T: 690 Episode Num: 138 Episode T: 2 Reward: 0.923
# Total T: 694 Episode Num: 139 Episode T: 4 Reward: 2.460
# Total T: 697 Episode Num: 140 Episode T: 3 Reward: 4.716
# Total T: 700 Episode Num: 141 Episode T: 3 Reward: 2.317
# Total T: 706 Episode Num: 142 Episode T: 6 Reward: 3.586
# Total T: 715 Episode Num: 143 Episode T: 9 Reward: 8.118
# Total T: 721 Episode Num: 144 Episode T: 6 Reward: 4.620
# Total T: 723 Episode Num: 145 Episode T: 2 Reward: 0.594
# Total T: 727 Episode Num: 146 Episode T: 4 Reward: 2.745
# Total T: 737 Episode Num: 147 Episode T: 10 Reward: 15.217
# Total T: 743 Episode Num: 148 Episode T: 6 Reward: 4.635
# Total T: 747 Episode Num: 149 Episode T: 4 Reward: 1.943
# Total T: 752 Episode Num: 150 Episode T: 5 Reward: 3.691
# Total T: 756 Episode Num: 151 Episode T: 4 Reward: 3.015
# Total T: 759 Episode Num: 152 Episode T: 3 Reward: 1.592
# Total T: 762 Episode Num: 153 Episode T: 3 Reward: 2.136
# Total T: 769 Episode Num: 154 Episode T: 7 Reward: 7.593
# Total T: 777 Episode Num: 155 Episode T: 8 Reward: 5.913
# Total T: 781 Episode Num: 156 Episode T: 4 Reward: 4.316
# Total T: 787 Episode Num: 157 Episode T: 6 Reward: 3.972
# Total T: 792 Episode Num: 158 Episode T: 5 Reward: 5.862
# Total T: 797 Episode Num: 159 Episode T: 5 Reward: 2.133
# Total T: 803 Episode Num: 160 Episode T: 6 Reward: 4.286
# Total T: 808 Episode Num: 161 Episode T: 5 Reward: 3.737
# Total T: 811 Episode Num: 162 Episode T: 3 Reward: 1.719
# Total T: 816 Episode Num: 163 Episode T: 5 Reward: 3.537
# Total T: 818 Episode Num: 164 Episode T: 2 Reward: 1.194
# Total T: 821 Episode Num: 165 Episode T: 3 Reward: 1.780
# Total T: 832 Episode Num: 166 Episode T: 11 Reward: 8.550
# Total T: 835 Episode Num: 167 Episode T: 3 Reward: 1.809
# Total T: 842 Episode Num: 168 Episode T: 7 Reward: 4.201
# Total T: 844 Episode Num: 169 Episode T: 2 Reward: 1.352
# Total T: 847 Episode Num: 170 Episode T: 3 Reward: 1.407
# Total T: 850 Episode Num: 171 Episode T: 3 Reward: 2.224
# Total T: 855 Episode Num: 172 Episode T: 5 Reward: 4.648
# Total T: 858 Episode Num: 173 Episode T: 3 Reward: 1.116
# Total T: 864 Episode Num: 174 Episode T: 6 Reward: 1.754
# Total T: 869 Episode Num: 175 Episode T: 5 Reward: 4.312
# Total T: 873 Episode Num: 176 Episode T: 4 Reward: 2.594
# Total T: 879 Episode Num: 177 Episode T: 6 Reward: 4.992
# Total T: 882 Episode Num: 178 Episode T: 3 Reward: 1.610
# Total T: 884 Episode Num: 179 Episode T: 2 Reward: -0.095
# Total T: 890 Episode Num: 180 Episode T: 6 Reward: 1.301
# Total T: 893 Episode Num: 181 Episode T: 3 Reward: -0.123
# Total T: 898 Episode Num: 182 Episode T: 5 Reward: 3.276
# Total T: 901 Episode Num: 183 Episode T: 3 Reward: 2.701
# Total T: 907 Episode Num: 184 Episode T: 6 Reward: 4.512
# Total T: 909 Episode Num: 185 Episode T: 2 Reward: 1.319
# Total T: 920 Episode Num: 186 Episode T: 11 Reward: 9.318
# Total T: 923 Episode Num: 187 Episode T: 3 Reward: 2.170
# Total T: 928 Episode Num: 188 Episode T: 5 Reward: 5.026
# Total T: 933 Episode Num: 189 Episode T: 5 Reward: 2.484
# Total T: 937 Episode Num: 190 Episode T: 4 Reward: 2.198
# Total T: 940 Episode Num: 191 Episode T: 3 Reward: 2.474
# Total T: 944 Episode Num: 192 Episode T: 4 Reward: 4.185
# Total T: 951 Episode Num: 193 Episode T: 7 Reward: 5.564
# Total T: 954 Episode Num: 194 Episode T: 3 Reward: -1.304
# Total T: 964 Episode Num: 195 Episode T: 10 Reward: 8.612
# Total T: 969 Episode Num: 196 Episode T: 5 Reward: 3.569
# Total T: 975 Episode Num: 197 Episode T: 6 Reward: 2.057
# Total T: 977 Episode Num: 198 Episode T: 2 Reward: -1.218
# Total T: 981 Episode Num: 199 Episode T: 4 Reward: 3.250
# Total T: 983 Episode Num: 200 Episode T: 2 Reward: 0.862
# Total T: 987 Episode Num: 201 Episode T: 4 Reward: 3.926
# Total T: 990 Episode Num: 202 Episode T: 3 Reward: 2.136
# Total T: 999 Episode Num: 203 Episode T: 9 Reward: 7.777
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 4.733
# ---------------------------------------
# Total T: 1004 Episode Num: 204 Episode T: 5 Reward: 3.878
# Total T: 1015 Episode Num: 205 Episode T: 11 Reward: 10.446
# Total T: 1018 Episode Num: 206 Episode T: 3 Reward: 1.548
# Total T: 1022 Episode Num: 207 Episode T: 4 Reward: 2.255
# Total T: 1025 Episode Num: 208 Episode T: 3 Reward: 1.652
# Total T: 1028 Episode Num: 209 Episode T: 3 Reward: 2.502
# Total T: 1036 Episode Num: 210 Episode T: 8 Reward: 4.568
# Total T: 1047 Episode Num: 211 Episode T: 11 Reward: 12.580
# Total T: 1050 Episode Num: 212 Episode T: 3 Reward: 1.267
# Total T: 1052 Episode Num: 213 Episode T: 2 Reward: 0.952
# Total T: 1055 Episode Num: 214 Episode T: 3 Reward: 1.964
# Total T: 1059 Episode Num: 215 Episode T: 4 Reward: 1.757
# Total T: 1070 Episode Num: 216 Episode T: 11 Reward: 4.719
# Total T: 1077 Episode Num: 217 Episode T: 7 Reward: 5.391
# Total T: 1079 Episode Num: 218 Episode T: 2 Reward: 1.758
# Total T: 1081 Episode Num: 219 Episode T: 2 Reward: 1.872
# Total T: 1084 Episode Num: 220 Episode T: 3 Reward: 1.608
# Total T: 1087 Episode Num: 221 Episode T: 3 Reward: -0.636
# Total T: 1089 Episode Num: 222 Episode T: 2 Reward: 0.555
# Total T: 1092 Episode Num: 223 Episode T: 3 Reward: 2.239
# Total T: 1094 Episode Num: 224 Episode T: 2 Reward: -1.610
# Total T: 1098 Episode Num: 225 Episode T: 4 Reward: 2.059
# Total T: 1101 Episode Num: 226 Episode T: 3 Reward: 2.340
# Total T: 1104 Episode Num: 227 Episode T: 3 Reward: 2.403
# Total T: 1111 Episode Num: 228 Episode T: 7 Reward: 4.049
# Total T: 1117 Episode Num: 229 Episode T: 6 Reward: 4.484
# Total T: 1123 Episode Num: 230 Episode T: 6 Reward: 3.273
# Total T: 1136 Episode Num: 231 Episode T: 13 Reward: 11.279
# Total T: 1142 Episode Num: 232 Episode T: 6 Reward: 3.127
# Total T: 1144 Episode Num: 233 Episode T: 2 Reward: 2.345
# Total T: 1150 Episode Num: 234 Episode T: 6 Reward: 3.935
# Total T: 1155 Episode Num: 235 Episode T: 5 Reward: 4.767
# Total T: 1163 Episode Num: 236 Episode T: 8 Reward: 4.739
# Total T: 1167 Episode Num: 237 Episode T: 4 Reward: 1.987
# Total T: 1170 Episode Num: 238 Episode T: 3 Reward: 1.682
# Total T: 1174 Episode Num: 239 Episode T: 4 Reward: 1.939
# Total T: 1178 Episode Num: 240 Episode T: 4 Reward: 2.094
# Total T: 1186 Episode Num: 241 Episode T: 8 Reward: 8.810
# Total T: 1189 Episode Num: 242 Episode T: 3 Reward: 0.150
# Total T: 1193 Episode Num: 243 Episode T: 4 Reward: 4.327
# Total T: 1201 Episode Num: 244 Episode T: 8 Reward: 5.733
# Total T: 1206 Episode Num: 245 Episode T: 5 Reward: 1.440
# Total T: 1210 Episode Num: 246 Episode T: 4 Reward: 3.313
# Total T: 1214 Episode Num: 247 Episode T: 4 Reward: 2.011
# Total T: 1217 Episode Num: 248 Episode T: 3 Reward: 2.171
# Total T: 1224 Episode Num: 249 Episode T: 7 Reward: 5.842
# Total T: 1228 Episode Num: 250 Episode T: 4 Reward: 3.498
# Total T: 1230 Episode Num: 251 Episode T: 2 Reward: 1.290
# Total T: 1232 Episode Num: 252 Episode T: 2 Reward: 1.424
# Total T: 1239 Episode Num: 253 Episode T: 7 Reward: 4.626
# Total T: 1244 Episode Num: 254 Episode T: 5 Reward: 4.038
# Total T: 1246 Episode Num: 255 Episode T: 2 Reward: 1.675
# Total T: 1252 Episode Num: 256 Episode T: 6 Reward: 5.484
# Total T: 1261 Episode Num: 257 Episode T: 9 Reward: 5.911
# Total T: 1268 Episode Num: 258 Episode T: 7 Reward: 5.968
# Total T: 1272 Episode Num: 259 Episode T: 4 Reward: 1.721
# Total T: 1275 Episode Num: 260 Episode T: 3 Reward: 2.453
# Total T: 1278 Episode Num: 261 Episode T: 3 Reward: 1.509
# Total T: 1284 Episode Num: 262 Episode T: 6 Reward: 2.833
# Total T: 1286 Episode Num: 263 Episode T: 2 Reward: 1.793
# Total T: 1288 Episode Num: 264 Episode T: 2 Reward: 1.463
# Total T: 1293 Episode Num: 265 Episode T: 5 Reward: 3.689
# Total T: 1298 Episode Num: 266 Episode T: 5 Reward: 3.082
# Total T: 1304 Episode Num: 267 Episode T: 6 Reward: 3.661
# Total T: 1309 Episode Num: 268 Episode T: 5 Reward: 3.999
# Total T: 1315 Episode Num: 269 Episode T: 6 Reward: 2.738
# Total T: 1317 Episode Num: 270 Episode T: 2 Reward: 1.671
# Total T: 1321 Episode Num: 271 Episode T: 4 Reward: 3.421
# Total T: 1331 Episode Num: 272 Episode T: 10 Reward: 9.126
# Total T: 1338 Episode Num: 273 Episode T: 7 Reward: 5.610
# Total T: 1343 Episode Num: 274 Episode T: 5 Reward: 2.235
# Total T: 1347 Episode Num: 275 Episode T: 4 Reward: 2.013
# Total T: 1354 Episode Num: 276 Episode T: 7 Reward: 5.775
# Total T: 1360 Episode Num: 277 Episode T: 6 Reward: 1.869
# Total T: 1365 Episode Num: 278 Episode T: 5 Reward: 3.993
# Total T: 1368 Episode Num: 279 Episode T: 3 Reward: 2.381
# Total T: 1373 Episode Num: 280 Episode T: 5 Reward: 1.847
# Total T: 1379 Episode Num: 281 Episode T: 6 Reward: 4.687
# Total T: 1382 Episode Num: 282 Episode T: 3 Reward: 2.012
# Total T: 1393 Episode Num: 283 Episode T: 11 Reward: 12.775
# Total T: 1396 Episode Num: 284 Episode T: 3 Reward: 1.434
# Total T: 1400 Episode Num: 285 Episode T: 4 Reward: 3.228
# Total T: 1409 Episode Num: 286 Episode T: 9 Reward: 8.355
# Total T: 1413 Episode Num: 287 Episode T: 4 Reward: 1.809
# Total T: 1418 Episode Num: 288 Episode T: 5 Reward: 3.198
# Total T: 1421 Episode Num: 289 Episode T: 3 Reward: 1.862
# Total T: 1424 Episode Num: 290 Episode T: 3 Reward: 2.058
# Total T: 1436 Episode Num: 291 Episode T: 12 Reward: 7.479
# Total T: 1442 Episode Num: 292 Episode T: 6 Reward: 3.460
# Total T: 1448 Episode Num: 293 Episode T: 6 Reward: 3.081
# Total T: 1450 Episode Num: 294 Episode T: 2 Reward: 1.508
# Total T: 1454 Episode Num: 295 Episode T: 4 Reward: 2.764
# Total T: 1457 Episode Num: 296 Episode T: 3 Reward: 1.581
# Total T: 1466 Episode Num: 297 Episode T: 9 Reward: 4.862
# Total T: 1471 Episode Num: 298 Episode T: 5 Reward: 3.726
# Total T: 1476 Episode Num: 299 Episode T: 5 Reward: 1.978
# Total T: 1480 Episode Num: 300 Episode T: 4 Reward: 2.791
# Total T: 1487 Episode Num: 301 Episode T: 7 Reward: 4.114
# Total T: 1489 Episode Num: 302 Episode T: 2 Reward: 1.345
# Total T: 1494 Episode Num: 303 Episode T: 5 Reward: 3.064
# Total T: 1500 Episode Num: 304 Episode T: 6 Reward: 5.217
# Total T: 1504 Episode Num: 305 Episode T: 4 Reward: 2.351
# Total T: 1508 Episode Num: 306 Episode T: 4 Reward: 3.795
# Total T: 1512 Episode Num: 307 Episode T: 4 Reward: 2.062
# Total T: 1516 Episode Num: 308 Episode T: 4 Reward: 3.036
# Total T: 1519 Episode Num: 309 Episode T: 3 Reward: 2.551
# Total T: 1523 Episode Num: 310 Episode T: 4 Reward: 1.459
# Total T: 1529 Episode Num: 311 Episode T: 6 Reward: 3.481
# Total T: 1537 Episode Num: 312 Episode T: 8 Reward: 13.023
# Total T: 1541 Episode Num: 313 Episode T: 4 Reward: 3.595
# Total T: 1545 Episode Num: 314 Episode T: 4 Reward: 2.924
# Total T: 1553 Episode Num: 315 Episode T: 8 Reward: 5.882
# Total T: 1557 Episode Num: 316 Episode T: 4 Reward: 2.785
# Total T: 1559 Episode Num: 317 Episode T: 2 Reward: 1.579
# Total T: 1565 Episode Num: 318 Episode T: 6 Reward: 3.941
# Total T: 1570 Episode Num: 319 Episode T: 5 Reward: 4.898
# Total T: 1572 Episode Num: 320 Episode T: 2 Reward: 1.857
# Total T: 1577 Episode Num: 321 Episode T: 5 Reward: 5.187
# Total T: 1580 Episode Num: 322 Episode T: 3 Reward: 4.022
# Total T: 1593 Episode Num: 323 Episode T: 13 Reward: 10.978
# Total T: 1598 Episode Num: 324 Episode T: 5 Reward: 3.792
# Total T: 1607 Episode Num: 325 Episode T: 9 Reward: 10.385
# Total T: 1610 Episode Num: 326 Episode T: 3 Reward: 1.622
# Total T: 1617 Episode Num: 327 Episode T: 7 Reward: 4.365
# Total T: 1624 Episode Num: 328 Episode T: 7 Reward: 4.832
# Total T: 1630 Episode Num: 329 Episode T: 6 Reward: 5.708
# Total T: 1633 Episode Num: 330 Episode T: 3 Reward: 2.401
# Total T: 1638 Episode Num: 331 Episode T: 5 Reward: 4.565
# Total T: 1641 Episode Num: 332 Episode T: 3 Reward: 1.922
# Total T: 1649 Episode Num: 333 Episode T: 8 Reward: 3.043
# Total T: 1653 Episode Num: 334 Episode T: 4 Reward: 1.245
# Total T: 1656 Episode Num: 335 Episode T: 3 Reward: 1.635
# Total T: 1659 Episode Num: 336 Episode T: 3 Reward: 1.937
# Total T: 1663 Episode Num: 337 Episode T: 4 Reward: 2.625
# Total T: 1665 Episode Num: 338 Episode T: 2 Reward: -2.027
# Total T: 1675 Episode Num: 339 Episode T: 10 Reward: 7.722
# Total T: 1679 Episode Num: 340 Episode T: 4 Reward: 2.272
# Total T: 1695 Episode Num: 341 Episode T: 16 Reward: 16.114
# Total T: 1702 Episode Num: 342 Episode T: 7 Reward: 3.936
# Total T: 1705 Episode Num: 343 Episode T: 3 Reward: 2.638
# Total T: 1710 Episode Num: 344 Episode T: 5 Reward: 3.669
# Total T: 1717 Episode Num: 345 Episode T: 7 Reward: 2.907
# Total T: 1720 Episode Num: 346 Episode T: 3 Reward: 1.563
# Total T: 1726 Episode Num: 347 Episode T: 6 Reward: 3.881
# Total T: 1729 Episode Num: 348 Episode T: 3 Reward: 2.234
# Total T: 1734 Episode Num: 349 Episode T: 5 Reward: 3.424
# Total T: 1742 Episode Num: 350 Episode T: 8 Reward: 3.913
# Total T: 1745 Episode Num: 351 Episode T: 3 Reward: 4.196
# Total T: 1750 Episode Num: 352 Episode T: 5 Reward: 3.423
# Total T: 1756 Episode Num: 353 Episode T: 6 Reward: 3.944
# Total T: 1761 Episode Num: 354 Episode T: 5 Reward: 4.302
# Total T: 1763 Episode Num: 355 Episode T: 2 Reward: 1.090
# Total T: 1767 Episode Num: 356 Episode T: 4 Reward: 0.182
# Total T: 1772 Episode Num: 357 Episode T: 5 Reward: 4.461
# Total T: 1776 Episode Num: 358 Episode T: 4 Reward: 2.305
# Total T: 1780 Episode Num: 359 Episode T: 4 Reward: 3.348
# Total T: 1783 Episode Num: 360 Episode T: 3 Reward: 2.174
# Total T: 1787 Episode Num: 361 Episode T: 4 Reward: 3.314
# Total T: 1789 Episode Num: 362 Episode T: 2 Reward: 1.380
# Total T: 1797 Episode Num: 363 Episode T: 8 Reward: 7.025
# Total T: 1802 Episode Num: 364 Episode T: 5 Reward: 2.004
# Total T: 1804 Episode Num: 365 Episode T: 2 Reward: 1.391
# Total T: 1809 Episode Num: 366 Episode T: 5 Reward: 2.488
# Total T: 1812 Episode Num: 367 Episode T: 3 Reward: 0.554
# Total T: 1814 Episode Num: 368 Episode T: 2 Reward: 1.597
# Total T: 1817 Episode Num: 369 Episode T: 3 Reward: 2.421
# Total T: 1820 Episode Num: 370 Episode T: 3 Reward: 2.301
# Total T: 1822 Episode Num: 371 Episode T: 2 Reward: 1.740
# Total T: 1831 Episode Num: 372 Episode T: 9 Reward: 7.667
# Total T: 1835 Episode Num: 373 Episode T: 4 Reward: 3.573
# Total T: 1838 Episode Num: 374 Episode T: 3 Reward: 1.821
# Total T: 1845 Episode Num: 375 Episode T: 7 Reward: 7.069
# Total T: 1851 Episode Num: 376 Episode T: 6 Reward: 8.169
# Total T: 1862 Episode Num: 377 Episode T: 11 Reward: 7.842
# Total T: 1864 Episode Num: 378 Episode T: 2 Reward: 2.204
# Total T: 1866 Episode Num: 379 Episode T: 2 Reward: 1.679
# Total T: 1871 Episode Num: 380 Episode T: 5 Reward: 2.635
# Total T: 1874 Episode Num: 381 Episode T: 3 Reward: 1.820
# Total T: 1879 Episode Num: 382 Episode T: 5 Reward: 3.225
# Total T: 1882 Episode Num: 383 Episode T: 3 Reward: 1.618
# Total T: 1888 Episode Num: 384 Episode T: 6 Reward: 5.386
# Total T: 1891 Episode Num: 385 Episode T: 3 Reward: 1.424
# Total T: 1895 Episode Num: 386 Episode T: 4 Reward: 3.383
# Total T: 1901 Episode Num: 387 Episode T: 6 Reward: 4.899
# Total T: 1908 Episode Num: 388 Episode T: 7 Reward: 5.942
# Total T: 1911 Episode Num: 389 Episode T: 3 Reward: 2.562
# Total T: 1916 Episode Num: 390 Episode T: 5 Reward: -0.627
# Total T: 1921 Episode Num: 391 Episode T: 5 Reward: 3.880
# Total T: 1924 Episode Num: 392 Episode T: 3 Reward: 1.814
# Total T: 1927 Episode Num: 393 Episode T: 3 Reward: 1.974
# Total T: 1929 Episode Num: 394 Episode T: 2 Reward: 1.982
# Total T: 1931 Episode Num: 395 Episode T: 2 Reward: 2.944
# Total T: 1933 Episode Num: 396 Episode T: 2 Reward: 1.382
# Total T: 1939 Episode Num: 397 Episode T: 6 Reward: 2.237
# Total T: 1945 Episode Num: 398 Episode T: 6 Reward: 4.363
# Total T: 1947 Episode Num: 399 Episode T: 2 Reward: 0.997
# Total T: 1952 Episode Num: 400 Episode T: 5 Reward: 3.853
# Total T: 1957 Episode Num: 401 Episode T: 5 Reward: 2.223
# Total T: 1960 Episode Num: 402 Episode T: 3 Reward: 0.509
# Total T: 1964 Episode Num: 403 Episode T: 4 Reward: 2.507
# Total T: 1967 Episode Num: 404 Episode T: 3 Reward: 2.231
# Total T: 1972 Episode Num: 405 Episode T: 5 Reward: 2.051
# Total T: 1975 Episode Num: 406 Episode T: 3 Reward: 1.524
# Total T: 1982 Episode Num: 407 Episode T: 7 Reward: 4.797
# Total T: 1986 Episode Num: 408 Episode T: 4 Reward: 3.188
# Total T: 1989 Episode Num: 409 Episode T: 3 Reward: 2.427
# Total T: 1998 Episode Num: 410 Episode T: 9 Reward: 4.660
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 4.733
# ---------------------------------------
# Total T: 2003 Episode Num: 411 Episode T: 5 Reward: -0.796
# Total T: 2005 Episode Num: 412 Episode T: 2 Reward: 1.757
# Total T: 2016 Episode Num: 413 Episode T: 11 Reward: 8.046
# Total T: 2022 Episode Num: 414 Episode T: 6 Reward: 5.165
# Total T: 2029 Episode Num: 415 Episode T: 7 Reward: 3.361
# Total T: 2031 Episode Num: 416 Episode T: 2 Reward: 1.422
# Total T: 2041 Episode Num: 417 Episode T: 10 Reward: 7.387
# Total T: 2044 Episode Num: 418 Episode T: 3 Reward: 1.910
# Total T: 2047 Episode Num: 419 Episode T: 3 Reward: 3.120
# Total T: 2059 Episode Num: 420 Episode T: 12 Reward: 9.635
# Total T: 2067 Episode Num: 421 Episode T: 8 Reward: 6.658
# Total T: 2069 Episode Num: 422 Episode T: 2 Reward: 1.636
# Total T: 2073 Episode Num: 423 Episode T: 4 Reward: 3.558
# Total T: 2087 Episode Num: 424 Episode T: 14 Reward: 16.240
# Total T: 2089 Episode Num: 425 Episode T: 2 Reward: 2.221
# Total T: 2091 Episode Num: 426 Episode T: 2 Reward: 0.229
# Total T: 2095 Episode Num: 427 Episode T: 4 Reward: 3.308
# Total T: 2098 Episode Num: 428 Episode T: 3 Reward: 1.558
# Total T: 2103 Episode Num: 429 Episode T: 5 Reward: 3.249
# Total T: 2107 Episode Num: 430 Episode T: 4 Reward: 1.993
# Total T: 2110 Episode Num: 431 Episode T: 3 Reward: 2.172
# Total T: 2117 Episode Num: 432 Episode T: 7 Reward: 11.366
# Total T: 2120 Episode Num: 433 Episode T: 3 Reward: 2.104
# Total T: 2124 Episode Num: 434 Episode T: 4 Reward: 4.069
# Total T: 2128 Episode Num: 435 Episode T: 4 Reward: 2.918
# Total T: 2131 Episode Num: 436 Episode T: 3 Reward: 1.318
# Total T: 2135 Episode Num: 437 Episode T: 4 Reward: 0.121
# Total T: 2138 Episode Num: 438 Episode T: 3 Reward: 1.719
# Total T: 2142 Episode Num: 439 Episode T: 4 Reward: 3.242
# Total T: 2150 Episode Num: 440 Episode T: 8 Reward: 7.951
# Total T: 2157 Episode Num: 441 Episode T: 7 Reward: 2.960
# Total T: 2162 Episode Num: 442 Episode T: 5 Reward: 1.490
# Total T: 2164 Episode Num: 443 Episode T: 2 Reward: 0.029
# Total T: 2169 Episode Num: 444 Episode T: 5 Reward: 3.318
# Total T: 2176 Episode Num: 445 Episode T: 7 Reward: 5.139
# Total T: 2185 Episode Num: 446 Episode T: 9 Reward: 7.270
# Total T: 2187 Episode Num: 447 Episode T: 2 Reward: 0.749
# Total T: 2191 Episode Num: 448 Episode T: 4 Reward: 1.695
# Total T: 2195 Episode Num: 449 Episode T: 4 Reward: 1.892
# Total T: 2198 Episode Num: 450 Episode T: 3 Reward: 1.922
# Total T: 2203 Episode Num: 451 Episode T: 5 Reward: 3.410
# Total T: 2207 Episode Num: 452 Episode T: 4 Reward: 2.272
# Total T: 2215 Episode Num: 453 Episode T: 8 Reward: 4.405
# Total T: 2217 Episode Num: 454 Episode T: 2 Reward: 1.554
# Total T: 2219 Episode Num: 455 Episode T: 2 Reward: 1.878
# Total T: 2226 Episode Num: 456 Episode T: 7 Reward: 5.077
# Total T: 2230 Episode Num: 457 Episode T: 4 Reward: 2.138
# Total T: 2232 Episode Num: 458 Episode T: 2 Reward: 0.632
# Total T: 2236 Episode Num: 459 Episode T: 4 Reward: 3.054
# Total T: 2242 Episode Num: 460 Episode T: 6 Reward: 6.884
# Total T: 2247 Episode Num: 461 Episode T: 5 Reward: 2.998
# Total T: 2254 Episode Num: 462 Episode T: 7 Reward: 5.547
# Total T: 2264 Episode Num: 463 Episode T: 10 Reward: 7.471
# Total T: 2268 Episode Num: 464 Episode T: 4 Reward: 2.351
# Total T: 2273 Episode Num: 465 Episode T: 5 Reward: 3.721
# Total T: 2279 Episode Num: 466 Episode T: 6 Reward: 3.672
# Total T: 2284 Episode Num: 467 Episode T: 5 Reward: 3.513
# Total T: 2287 Episode Num: 468 Episode T: 3 Reward: 2.332
# Total T: 2299 Episode Num: 469 Episode T: 12 Reward: 10.386
# Total T: 2301 Episode Num: 470 Episode T: 2 Reward: 1.475
# Total T: 2303 Episode Num: 471 Episode T: 2 Reward: 1.256
# Total T: 2307 Episode Num: 472 Episode T: 4 Reward: 3.811
# Total T: 2311 Episode Num: 473 Episode T: 4 Reward: 7.381
# Total T: 2316 Episode Num: 474 Episode T: 5 Reward: 4.880
# Total T: 2319 Episode Num: 475 Episode T: 3 Reward: 1.524
# Total T: 2324 Episode Num: 476 Episode T: 5 Reward: 0.964
# Total T: 2326 Episode Num: 477 Episode T: 2 Reward: 0.774
# Total T: 2332 Episode Num: 478 Episode T: 6 Reward: 3.516
# Total T: 2335 Episode Num: 479 Episode T: 3 Reward: 2.010
# Total T: 2339 Episode Num: 480 Episode T: 4 Reward: 2.741
# Total T: 2349 Episode Num: 481 Episode T: 10 Reward: 9.213
# Total T: 2355 Episode Num: 482 Episode T: 6 Reward: 4.304
# Total T: 2358 Episode Num: 483 Episode T: 3 Reward: 2.486
# Total T: 2361 Episode Num: 484 Episode T: 3 Reward: 2.141
# Total T: 2365 Episode Num: 485 Episode T: 4 Reward: 2.778
# Total T: 2369 Episode Num: 486 Episode T: 4 Reward: 2.668
# Total T: 2373 Episode Num: 487 Episode T: 4 Reward: 2.557
# Total T: 2376 Episode Num: 488 Episode T: 3 Reward: 1.780
# Total T: 2380 Episode Num: 489 Episode T: 4 Reward: 1.934
# Total T: 2388 Episode Num: 490 Episode T: 8 Reward: 6.069
# Total T: 2391 Episode Num: 491 Episode T: 3 Reward: 2.626
# Total T: 2394 Episode Num: 492 Episode T: 3 Reward: 2.410
# Total T: 2396 Episode Num: 493 Episode T: 2 Reward: 1.696
# Total T: 2408 Episode Num: 494 Episode T: 12 Reward: 10.252
# Total T: 2414 Episode Num: 495 Episode T: 6 Reward: 4.473
# Total T: 2416 Episode Num: 496 Episode T: 2 Reward: 1.371
# Total T: 2421 Episode Num: 497 Episode T: 5 Reward: 5.075
# Total T: 2428 Episode Num: 498 Episode T: 7 Reward: 7.060
# Total T: 2431 Episode Num: 499 Episode T: 3 Reward: 1.725
# Total T: 2439 Episode Num: 500 Episode T: 8 Reward: 6.391
# Total T: 2443 Episode Num: 501 Episode T: 4 Reward: 3.118
# Total T: 2448 Episode Num: 502 Episode T: 5 Reward: 2.608
# Total T: 2459 Episode Num: 503 Episode T: 11 Reward: 8.717
# Total T: 2469 Episode Num: 504 Episode T: 10 Reward: 6.984
# Total T: 2471 Episode Num: 505 Episode T: 2 Reward: -0.657
# Total T: 2479 Episode Num: 506 Episode T: 8 Reward: 6.435
# Total T: 2482 Episode Num: 507 Episode T: 3 Reward: 3.018
# Total T: 2487 Episode Num: 508 Episode T: 5 Reward: 3.927
# Total T: 2495 Episode Num: 509 Episode T: 8 Reward: 6.599
# Total T: 2497 Episode Num: 510 Episode T: 2 Reward: 1.545
# Total T: 2503 Episode Num: 511 Episode T: 6 Reward: 2.142
# Total T: 2508 Episode Num: 512 Episode T: 5 Reward: 3.699
# Total T: 2513 Episode Num: 513 Episode T: 5 Reward: 5.779
# Total T: 2516 Episode Num: 514 Episode T: 3 Reward: 2.694
# Total T: 2519 Episode Num: 515 Episode T: 3 Reward: 3.119
# Total T: 2526 Episode Num: 516 Episode T: 7 Reward: 6.336
# Total T: 2535 Episode Num: 517 Episode T: 9 Reward: 7.234
# Total T: 2537 Episode Num: 518 Episode T: 2 Reward: 1.661
# Total T: 2540 Episode Num: 519 Episode T: 3 Reward: 2.830
# Total T: 2543 Episode Num: 520 Episode T: 3 Reward: 1.676
# Total T: 2547 Episode Num: 521 Episode T: 4 Reward: 3.121
# Total T: 2549 Episode Num: 522 Episode T: 2 Reward: 0.558
# Total T: 2554 Episode Num: 523 Episode T: 5 Reward: 3.810
# Total T: 2557 Episode Num: 524 Episode T: 3 Reward: 1.849
# Total T: 2561 Episode Num: 525 Episode T: 4 Reward: 1.035
# Total T: 2568 Episode Num: 526 Episode T: 7 Reward: 6.888
# Total T: 2577 Episode Num: 527 Episode T: 9 Reward: 9.870
# Total T: 2585 Episode Num: 528 Episode T: 8 Reward: 5.566
# Total T: 2589 Episode Num: 529 Episode T: 4 Reward: 2.469
# Total T: 2595 Episode Num: 530 Episode T: 6 Reward: 7.107
# Total T: 2598 Episode Num: 531 Episode T: 3 Reward: 2.775
# Total T: 2601 Episode Num: 532 Episode T: 3 Reward: 2.012
# Total T: 2604 Episode Num: 533 Episode T: 3 Reward: 1.630
# Total T: 2607 Episode Num: 534 Episode T: 3 Reward: 1.467
# Total T: 2610 Episode Num: 535 Episode T: 3 Reward: 2.581
# Total T: 2614 Episode Num: 536 Episode T: 4 Reward: 2.785
# Total T: 2618 Episode Num: 537 Episode T: 4 Reward: 2.627
# Total T: 2623 Episode Num: 538 Episode T: 5 Reward: 3.338
# Total T: 2625 Episode Num: 539 Episode T: 2 Reward: 1.956
# Total T: 2628 Episode Num: 540 Episode T: 3 Reward: 1.211
# Total T: 2630 Episode Num: 541 Episode T: 2 Reward: -0.263
# Total T: 2632 Episode Num: 542 Episode T: 2 Reward: 1.327
# Total T: 2636 Episode Num: 543 Episode T: 4 Reward: 2.096
# Total T: 2641 Episode Num: 544 Episode T: 5 Reward: 2.981
# Total T: 2643 Episode Num: 545 Episode T: 2 Reward: 2.196
# Total T: 2651 Episode Num: 546 Episode T: 8 Reward: 5.804
# Total T: 2655 Episode Num: 547 Episode T: 4 Reward: 3.299
# Total T: 2658 Episode Num: 548 Episode T: 3 Reward: 1.987
# Total T: 2661 Episode Num: 549 Episode T: 3 Reward: 1.484
# Total T: 2663 Episode Num: 550 Episode T: 2 Reward: -1.561
# Total T: 2666 Episode Num: 551 Episode T: 3 Reward: 2.539
# Total T: 2670 Episode Num: 552 Episode T: 4 Reward: 2.551
# Total T: 2673 Episode Num: 553 Episode T: 3 Reward: 1.867
# Total T: 2675 Episode Num: 554 Episode T: 2 Reward: 1.429
# Total T: 2678 Episode Num: 555 Episode T: 3 Reward: 1.934
# Total T: 2681 Episode Num: 556 Episode T: 3 Reward: 1.967
# Total T: 2687 Episode Num: 557 Episode T: 6 Reward: 4.131
# Total T: 2691 Episode Num: 558 Episode T: 4 Reward: 2.961
# Total T: 2696 Episode Num: 559 Episode T: 5 Reward: 10.416
# Total T: 2700 Episode Num: 560 Episode T: 4 Reward: 2.505
# Total T: 2703 Episode Num: 561 Episode T: 3 Reward: 1.903
# Total T: 2705 Episode Num: 562 Episode T: 2 Reward: -1.411
# Total T: 2710 Episode Num: 563 Episode T: 5 Reward: 2.136
# Total T: 2720 Episode Num: 564 Episode T: 10 Reward: 9.875
# Total T: 2726 Episode Num: 565 Episode T: 6 Reward: 5.970
# Total T: 2732 Episode Num: 566 Episode T: 6 Reward: 2.269
# Total T: 2741 Episode Num: 567 Episode T: 9 Reward: 4.421
# Total T: 2747 Episode Num: 568 Episode T: 6 Reward: 4.597
# Total T: 2749 Episode Num: 569 Episode T: 2 Reward: 1.512
# Total T: 2751 Episode Num: 570 Episode T: 2 Reward: 1.669
# Total T: 2754 Episode Num: 571 Episode T: 3 Reward: 2.287
# Total T: 2758 Episode Num: 572 Episode T: 4 Reward: 1.868
# Total T: 2763 Episode Num: 573 Episode T: 5 Reward: 2.159
# Total T: 2768 Episode Num: 574 Episode T: 5 Reward: 3.804
# Total T: 2771 Episode Num: 575 Episode T: 3 Reward: 2.695
# Total T: 2784 Episode Num: 576 Episode T: 13 Reward: 11.987
# Total T: 2788 Episode Num: 577 Episode T: 4 Reward: 2.832
# Total T: 2791 Episode Num: 578 Episode T: 3 Reward: 2.652
# Total T: 2793 Episode Num: 579 Episode T: 2 Reward: 1.253
# Total T: 2797 Episode Num: 580 Episode T: 4 Reward: 1.579
# Total T: 2800 Episode Num: 581 Episode T: 3 Reward: 1.483
# Total T: 2802 Episode Num: 582 Episode T: 2 Reward: 0.570
# Total T: 2809 Episode Num: 583 Episode T: 7 Reward: 4.716
# Total T: 2814 Episode Num: 584 Episode T: 5 Reward: 3.930
# Total T: 2818 Episode Num: 585 Episode T: 4 Reward: 2.809
# Total T: 2822 Episode Num: 586 Episode T: 4 Reward: 2.494
# Total T: 2828 Episode Num: 587 Episode T: 6 Reward: 5.831
# Total T: 2833 Episode Num: 588 Episode T: 5 Reward: 3.293
# Total T: 2837 Episode Num: 589 Episode T: 4 Reward: 2.222
# Total T: 2842 Episode Num: 590 Episode T: 5 Reward: 1.487
# Total T: 2845 Episode Num: 591 Episode T: 3 Reward: 1.639
# Total T: 2851 Episode Num: 592 Episode T: 6 Reward: 5.488
# Total T: 2853 Episode Num: 593 Episode T: 2 Reward: 1.501
# Total T: 2857 Episode Num: 594 Episode T: 4 Reward: 1.947
# Total T: 2860 Episode Num: 595 Episode T: 3 Reward: 1.582
# Total T: 2864 Episode Num: 596 Episode T: 4 Reward: 2.113
# Total T: 2869 Episode Num: 597 Episode T: 5 Reward: 1.751
# Total T: 2874 Episode Num: 598 Episode T: 5 Reward: 3.155
# Total T: 2876 Episode Num: 599 Episode T: 2 Reward: 1.145
# Total T: 2881 Episode Num: 600 Episode T: 5 Reward: 5.071
# Total T: 2887 Episode Num: 601 Episode T: 6 Reward: 4.427
# Total T: 2891 Episode Num: 602 Episode T: 4 Reward: 1.947
# Total T: 2893 Episode Num: 603 Episode T: 2 Reward: 0.938
# Total T: 2899 Episode Num: 604 Episode T: 6 Reward: 6.969
# Total T: 2902 Episode Num: 605 Episode T: 3 Reward: 2.084
# Total T: 2908 Episode Num: 606 Episode T: 6 Reward: 4.815
# Total T: 2913 Episode Num: 607 Episode T: 5 Reward: 4.372
# Total T: 2921 Episode Num: 608 Episode T: 8 Reward: 4.707
# Total T: 2924 Episode Num: 609 Episode T: 3 Reward: 1.561
# Total T: 2926 Episode Num: 610 Episode T: 2 Reward: 0.515
# Total T: 2932 Episode Num: 611 Episode T: 6 Reward: 5.720
# Total T: 2936 Episode Num: 612 Episode T: 4 Reward: 3.952
# Total T: 2943 Episode Num: 613 Episode T: 7 Reward: 3.587
# Total T: 2946 Episode Num: 614 Episode T: 3 Reward: 2.013
# Total T: 2950 Episode Num: 615 Episode T: 4 Reward: 0.686
# Total T: 2953 Episode Num: 616 Episode T: 3 Reward: 0.974
# Total T: 2960 Episode Num: 617 Episode T: 7 Reward: 5.068
# Total T: 2966 Episode Num: 618 Episode T: 6 Reward: 4.057
# Total T: 2968 Episode Num: 619 Episode T: 2 Reward: 0.388
# Total T: 2975 Episode Num: 620 Episode T: 7 Reward: 5.712
# Total T: 2980 Episode Num: 621 Episode T: 5 Reward: 2.319
# Total T: 2985 Episode Num: 622 Episode T: 5 Reward: 3.814
# Total T: 2987 Episode Num: 623 Episode T: 2 Reward: 1.557
# Total T: 2991 Episode Num: 624 Episode T: 4 Reward: -1.344
# Total T: 2995 Episode Num: 625 Episode T: 4 Reward: 1.368
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 4.733
# ---------------------------------------
# Total T: 3001 Episode Num: 626 Episode T: 6 Reward: 3.669
# Total T: 3005 Episode Num: 627 Episode T: 4 Reward: 2.512
# Total T: 3008 Episode Num: 628 Episode T: 3 Reward: 2.263
# Total T: 3013 Episode Num: 629 Episode T: 5 Reward: 3.977
# Total T: 3015 Episode Num: 630 Episode T: 2 Reward: 1.627
# Total T: 3023 Episode Num: 631 Episode T: 8 Reward: 5.681
# Total T: 3027 Episode Num: 632 Episode T: 4 Reward: 5.459
# Total T: 3044 Episode Num: 633 Episode T: 17 Reward: 22.862
# Total T: 3051 Episode Num: 634 Episode T: 7 Reward: 4.626
# Total T: 3059 Episode Num: 635 Episode T: 8 Reward: 0.489
# Total T: 3063 Episode Num: 636 Episode T: 4 Reward: 3.404
# Total T: 3067 Episode Num: 637 Episode T: 4 Reward: 2.615
# Total T: 3077 Episode Num: 638 Episode T: 10 Reward: 7.559
# Total T: 3080 Episode Num: 639 Episode T: 3 Reward: 4.879
# Total T: 3082 Episode Num: 640 Episode T: 2 Reward: 0.289
# Total T: 3085 Episode Num: 641 Episode T: 3 Reward: 1.731
# Total T: 3090 Episode Num: 642 Episode T: 5 Reward: 3.304
# Total T: 3093 Episode Num: 643 Episode T: 3 Reward: 2.449
# Total T: 3099 Episode Num: 644 Episode T: 6 Reward: 5.763
# Total T: 3101 Episode Num: 645 Episode T: 2 Reward: 1.249
# Total T: 3105 Episode Num: 646 Episode T: 4 Reward: 1.806
# Total T: 3116 Episode Num: 647 Episode T: 11 Reward: 7.469
# Total T: 3123 Episode Num: 648 Episode T: 7 Reward: 4.653
# Total T: 3129 Episode Num: 649 Episode T: 6 Reward: 4.694
# Total T: 3136 Episode Num: 650 Episode T: 7 Reward: 4.065
# Total T: 3141 Episode Num: 651 Episode T: 5 Reward: 7.968
# Total T: 3145 Episode Num: 652 Episode T: 4 Reward: 2.942
# Total T: 3150 Episode Num: 653 Episode T: 5 Reward: 2.877
# Total T: 3156 Episode Num: 654 Episode T: 6 Reward: 5.543
# Total T: 3162 Episode Num: 655 Episode T: 6 Reward: 4.102
# Total T: 3165 Episode Num: 656 Episode T: 3 Reward: 2.408
# Total T: 3174 Episode Num: 657 Episode T: 9 Reward: 6.613
# Total T: 3177 Episode Num: 658 Episode T: 3 Reward: 1.675
# Total T: 3183 Episode Num: 659 Episode T: 6 Reward: 1.420
# Total T: 3185 Episode Num: 660 Episode T: 2 Reward: 1.220
# Total T: 3189 Episode Num: 661 Episode T: 4 Reward: 3.159
# Total T: 3192 Episode Num: 662 Episode T: 3 Reward: 1.473
# Total T: 3197 Episode Num: 663 Episode T: 5 Reward: 3.051
# Total T: 3205 Episode Num: 664 Episode T: 8 Reward: 8.208
# Total T: 3208 Episode Num: 665 Episode T: 3 Reward: 2.086
# Total T: 3211 Episode Num: 666 Episode T: 3 Reward: 1.940
# Total T: 3214 Episode Num: 667 Episode T: 3 Reward: 2.211
# Total T: 3219 Episode Num: 668 Episode T: 5 Reward: 3.976
# Total T: 3222 Episode Num: 669 Episode T: 3 Reward: 2.053
# Total T: 3225 Episode Num: 670 Episode T: 3 Reward: 1.454
# Total T: 3229 Episode Num: 671 Episode T: 4 Reward: 2.410
# Total T: 3233 Episode Num: 672 Episode T: 4 Reward: 1.359
# Total T: 3240 Episode Num: 673 Episode T: 7 Reward: 4.805
# Total T: 3242 Episode Num: 674 Episode T: 2 Reward: 0.679
# Total T: 3244 Episode Num: 675 Episode T: 2 Reward: 1.602
# Total T: 3249 Episode Num: 676 Episode T: 5 Reward: 3.459
# Total T: 3253 Episode Num: 677 Episode T: 4 Reward: 3.700
# Total T: 3256 Episode Num: 678 Episode T: 3 Reward: 2.459
# Total T: 3263 Episode Num: 679 Episode T: 7 Reward: 7.633
# Total T: 3268 Episode Num: 680 Episode T: 5 Reward: 3.848
# Total T: 3273 Episode Num: 681 Episode T: 5 Reward: 2.452
# Total T: 3276 Episode Num: 682 Episode T: 3 Reward: 2.543
# Total T: 3282 Episode Num: 683 Episode T: 6 Reward: 1.478
# Total T: 3290 Episode Num: 684 Episode T: 8 Reward: 5.354
# Total T: 3296 Episode Num: 685 Episode T: 6 Reward: 6.399
# Total T: 3299 Episode Num: 686 Episode T: 3 Reward: 1.638
# Total T: 3303 Episode Num: 687 Episode T: 4 Reward: 2.859
# Total T: 3306 Episode Num: 688 Episode T: 3 Reward: 2.975
# Total T: 3308 Episode Num: 689 Episode T: 2 Reward: 1.299
# Total T: 3310 Episode Num: 690 Episode T: 2 Reward: 1.765
# Total T: 3319 Episode Num: 691 Episode T: 9 Reward: 7.085
# Total T: 3324 Episode Num: 692 Episode T: 5 Reward: 4.395
# Total T: 3327 Episode Num: 693 Episode T: 3 Reward: 0.201
# Total T: 3329 Episode Num: 694 Episode T: 2 Reward: 2.796
# Total T: 3331 Episode Num: 695 Episode T: 2 Reward: 0.301
# Total T: 3337 Episode Num: 696 Episode T: 6 Reward: 3.965
# Total T: 3345 Episode Num: 697 Episode T: 8 Reward: 9.307
# Total T: 3348 Episode Num: 698 Episode T: 3 Reward: 2.866
# Total T: 3353 Episode Num: 699 Episode T: 5 Reward: 4.912
# Total T: 3358 Episode Num: 700 Episode T: 5 Reward: 1.514
# Total T: 3376 Episode Num: 701 Episode T: 18 Reward: 21.564
# Total T: 3379 Episode Num: 702 Episode T: 3 Reward: 2.493
# Total T: 3387 Episode Num: 703 Episode T: 8 Reward: 5.901
# Total T: 3391 Episode Num: 704 Episode T: 4 Reward: 2.521
# Total T: 3395 Episode Num: 705 Episode T: 4 Reward: 2.304
# Total T: 3400 Episode Num: 706 Episode T: 5 Reward: 2.762
# Total T: 3403 Episode Num: 707 Episode T: 3 Reward: 2.085
# Total T: 3407 Episode Num: 708 Episode T: 4 Reward: 1.701
# Total T: 3413 Episode Num: 709 Episode T: 6 Reward: 2.392
# Total T: 3416 Episode Num: 710 Episode T: 3 Reward: -0.515
# Total T: 3419 Episode Num: 711 Episode T: 3 Reward: -1.033
# Total T: 3422 Episode Num: 712 Episode T: 3 Reward: 2.642
# Total T: 3425 Episode Num: 713 Episode T: 3 Reward: 1.885
# Total T: 3432 Episode Num: 714 Episode T: 7 Reward: 5.163
# Total T: 3445 Episode Num: 715 Episode T: 13 Reward: 8.778
# Total T: 3447 Episode Num: 716 Episode T: 2 Reward: 1.433
# Total T: 3450 Episode Num: 717 Episode T: 3 Reward: 1.940
# Total T: 3453 Episode Num: 718 Episode T: 3 Reward: 1.270
# Total T: 3460 Episode Num: 719 Episode T: 7 Reward: 5.625
# Total T: 3463 Episode Num: 720 Episode T: 3 Reward: 0.721
# Total T: 3473 Episode Num: 721 Episode T: 10 Reward: 6.418
# Total T: 3478 Episode Num: 722 Episode T: 5 Reward: 1.919
# Total T: 3481 Episode Num: 723 Episode T: 3 Reward: 2.435
# Total T: 3486 Episode Num: 724 Episode T: 5 Reward: 3.889
# Total T: 3490 Episode Num: 725 Episode T: 4 Reward: 2.943
# Total T: 3499 Episode Num: 726 Episode T: 9 Reward: 5.252
# Total T: 3502 Episode Num: 727 Episode T: 3 Reward: 1.659
# Total T: 3504 Episode Num: 728 Episode T: 2 Reward: 2.321
# Total T: 3511 Episode Num: 729 Episode T: 7 Reward: 5.042
# Total T: 3513 Episode Num: 730 Episode T: 2 Reward: 1.622
# Total T: 3515 Episode Num: 731 Episode T: 2 Reward: 1.703
# Total T: 3521 Episode Num: 732 Episode T: 6 Reward: 2.665
# Total T: 3524 Episode Num: 733 Episode T: 3 Reward: 2.193
# Total T: 3528 Episode Num: 734 Episode T: 4 Reward: 3.279
# Total T: 3532 Episode Num: 735 Episode T: 4 Reward: 3.339
# Total T: 3535 Episode Num: 736 Episode T: 3 Reward: 2.095
# Total T: 3540 Episode Num: 737 Episode T: 5 Reward: 4.860
# Total T: 3553 Episode Num: 738 Episode T: 13 Reward: 6.516
# Total T: 3557 Episode Num: 739 Episode T: 4 Reward: 2.734
# Total T: 3562 Episode Num: 740 Episode T: 5 Reward: 5.201
# Total T: 3565 Episode Num: 741 Episode T: 3 Reward: 2.421
# Total T: 3567 Episode Num: 742 Episode T: 2 Reward: 1.962
# Total T: 3571 Episode Num: 743 Episode T: 4 Reward: 2.286
# Total T: 3574 Episode Num: 744 Episode T: 3 Reward: 2.094
# Total T: 3576 Episode Num: 745 Episode T: 2 Reward: 1.300
# Total T: 3580 Episode Num: 746 Episode T: 4 Reward: 3.152
# Total T: 3582 Episode Num: 747 Episode T: 2 Reward: 1.556
# Total T: 3587 Episode Num: 748 Episode T: 5 Reward: 3.282
# Total T: 3592 Episode Num: 749 Episode T: 5 Reward: 4.077
# Total T: 3594 Episode Num: 750 Episode T: 2 Reward: -0.845
# Total T: 3596 Episode Num: 751 Episode T: 2 Reward: 1.197
# Total T: 3599 Episode Num: 752 Episode T: 3 Reward: 2.833
# Total T: 3606 Episode Num: 753 Episode T: 7 Reward: 10.338
# Total T: 3615 Episode Num: 754 Episode T: 9 Reward: 7.304
# Total T: 3618 Episode Num: 755 Episode T: 3 Reward: 1.691
# Total T: 3623 Episode Num: 756 Episode T: 5 Reward: 2.857
# Total T: 3630 Episode Num: 757 Episode T: 7 Reward: 6.281
# Total T: 3633 Episode Num: 758 Episode T: 3 Reward: 2.214
# Total T: 3638 Episode Num: 759 Episode T: 5 Reward: 2.787
# Total T: 3643 Episode Num: 760 Episode T: 5 Reward: 3.041
# Total T: 3647 Episode Num: 761 Episode T: 4 Reward: 2.923
# Total T: 3652 Episode Num: 762 Episode T: 5 Reward: 3.884
# Total T: 3654 Episode Num: 763 Episode T: 2 Reward: 1.450
# Total T: 3658 Episode Num: 764 Episode T: 4 Reward: 2.922
# Total T: 3665 Episode Num: 765 Episode T: 7 Reward: 8.480
# Total T: 3669 Episode Num: 766 Episode T: 4 Reward: 3.867
# Total T: 3671 Episode Num: 767 Episode T: 2 Reward: 1.776
# Total T: 3676 Episode Num: 768 Episode T: 5 Reward: 2.569
# Total T: 3679 Episode Num: 769 Episode T: 3 Reward: 1.506
# Total T: 3683 Episode Num: 770 Episode T: 4 Reward: 1.064
# Total T: 3685 Episode Num: 771 Episode T: 2 Reward: 0.675
# Total T: 3700 Episode Num: 772 Episode T: 15 Reward: 14.898
# Total T: 3703 Episode Num: 773 Episode T: 3 Reward: 1.264
# Total T: 3705 Episode Num: 774 Episode T: 2 Reward: 1.461
# Total T: 3709 Episode Num: 775 Episode T: 4 Reward: 2.270
# Total T: 3714 Episode Num: 776 Episode T: 5 Reward: 4.464
# Total T: 3717 Episode Num: 777 Episode T: 3 Reward: 1.984
# Total T: 3720 Episode Num: 778 Episode T: 3 Reward: 0.611
# Total T: 3723 Episode Num: 779 Episode T: 3 Reward: 2.175
# Total T: 3731 Episode Num: 780 Episode T: 8 Reward: 6.044
# Total T: 3735 Episode Num: 781 Episode T: 4 Reward: 2.087
# Total T: 3737 Episode Num: 782 Episode T: 2 Reward: 1.344
# Total T: 3746 Episode Num: 783 Episode T: 9 Reward: 7.531
# Total T: 3750 Episode Num: 784 Episode T: 4 Reward: 1.441
# Total T: 3754 Episode Num: 785 Episode T: 4 Reward: 1.919
# Total T: 3768 Episode Num: 786 Episode T: 14 Reward: 13.423
# Total T: 3773 Episode Num: 787 Episode T: 5 Reward: 3.148
# Total T: 3776 Episode Num: 788 Episode T: 3 Reward: 1.520
# Total T: 3778 Episode Num: 789 Episode T: 2 Reward: 1.478
# Total T: 3782 Episode Num: 790 Episode T: 4 Reward: 4.620
# Total T: 3790 Episode Num: 791 Episode T: 8 Reward: 8.067
# Total T: 3793 Episode Num: 792 Episode T: 3 Reward: 2.165
# Total T: 3796 Episode Num: 793 Episode T: 3 Reward: 1.430
# Total T: 3800 Episode Num: 794 Episode T: 4 Reward: 2.873
# Total T: 3803 Episode Num: 795 Episode T: 3 Reward: 2.619
# Total T: 3807 Episode Num: 796 Episode T: 4 Reward: 2.677
# Total T: 3811 Episode Num: 797 Episode T: 4 Reward: 2.601
# Total T: 3827 Episode Num: 798 Episode T: 16 Reward: 16.049
# Total T: 3833 Episode Num: 799 Episode T: 6 Reward: 4.050
# Total T: 3851 Episode Num: 800 Episode T: 18 Reward: 15.532
# Total T: 3861 Episode Num: 801 Episode T: 10 Reward: 8.501
# Total T: 3863 Episode Num: 802 Episode T: 2 Reward: 1.606
# Total T: 3865 Episode Num: 803 Episode T: 2 Reward: 1.584
# Total T: 3873 Episode Num: 804 Episode T: 8 Reward: 5.436
# Total T: 3876 Episode Num: 805 Episode T: 3 Reward: 1.088
# Total T: 3880 Episode Num: 806 Episode T: 4 Reward: 4.449
# Total T: 3882 Episode Num: 807 Episode T: 2 Reward: 1.540
# Total T: 3886 Episode Num: 808 Episode T: 4 Reward: 1.144
# Total T: 3894 Episode Num: 809 Episode T: 8 Reward: 4.259
# Total T: 3897 Episode Num: 810 Episode T: 3 Reward: 3.063
# Total T: 3900 Episode Num: 811 Episode T: 3 Reward: 1.862
# Total T: 3908 Episode Num: 812 Episode T: 8 Reward: 7.452
# Total T: 3912 Episode Num: 813 Episode T: 4 Reward: 2.532
# Total T: 3921 Episode Num: 814 Episode T: 9 Reward: 6.331
# Total T: 3925 Episode Num: 815 Episode T: 4 Reward: 3.279
# Total T: 3928 Episode Num: 816 Episode T: 3 Reward: 2.731
# Total T: 3931 Episode Num: 817 Episode T: 3 Reward: 0.940
# Total T: 3938 Episode Num: 818 Episode T: 7 Reward: 3.473
# ...
# ---------------------------------------
# Total T: 188079 Episode Num: 3029 Episode T: 1000 Reward: 2022.559
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1112.038
# ---------------------------------------
# Total T: 189079 Episode Num: 3030 Episode T: 1000 Reward: 2012.928
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 779.484
# ---------------------------------------
# Total T: 190079 Episode Num: 3031 Episode T: 1000 Reward: 2074.555
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1074.429
# ---------------------------------------
# Total T: 191079 Episode Num: 3032 Episode T: 1000 Reward: 2142.378
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1318.064
# ---------------------------------------
# Total T: 192079 Episode Num: 3033 Episode T: 1000 Reward: 2017.825
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1118.339
# ---------------------------------------
# Total T: 193079 Episode Num: 3034 Episode T: 1000 Reward: 2137.847
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1303.436
# ---------------------------------------
# Total T: 194079 Episode Num: 3035 Episode T: 1000 Reward: 2083.406
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1275.267
# ---------------------------------------
# Total T: 195079 Episode Num: 3036 Episode T: 1000 Reward: 2073.365
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1054.644
# ---------------------------------------
# Total T: 196079 Episode Num: 3037 Episode T: 1000 Reward: 2071.372
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 660.783
# ---------------------------------------
# Total T: 197079 Episode Num: 3038 Episode T: 1000 Reward: 2048.728
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1085.872
# ---------------------------------------
# Total T: 198079 Episode Num: 3039 Episode T: 1000 Reward: 1968.786
# Total T: 198097 Episode Num: 3040 Episode T: 18 Reward: 5.105
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1017.696
# ---------------------------------------
# Total T: 199097 Episode Num: 3041 Episode T: 1000 Reward: 2034.078
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1017.090
# ---------------------------------------
# Total T: 200097 Episode Num: 3042 Episode T: 1000 Reward: 1969.354
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1216.496
# ---------------------------------------
# Total T: 201097 Episode Num: 3043 Episode T: 1000 Reward: 1964.950
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 876.232
# ---------------------------------------
# Total T: 202097 Episode Num: 3044 Episode T: 1000 Reward: 2076.455
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1256.346
# ---------------------------------------
# Total T: 203097 Episode Num: 3045 Episode T: 1000 Reward: 2047.916
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1087.068
# ---------------------------------------
# Total T: 204097 Episode Num: 3046 Episode T: 1000 Reward: 2074.018
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1041.810
# ---------------------------------------
# Total T: 205097 Episode Num: 3047 Episode T: 1000 Reward: 2022.489
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1229.496
# ---------------------------------------
# Total T: 206097 Episode Num: 3048 Episode T: 1000 Reward: 2016.260
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1260.880
# ---------------------------------------
# Total T: 207097 Episode Num: 3049 Episode T: 1000 Reward: 2107.176
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 789.732
# ---------------------------------------
# Total T: 208097 Episode Num: 3050 Episode T: 1000 Reward: 2046.183
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 970.253
# ---------------------------------------
# Total T: 209097 Episode Num: 3051 Episode T: 1000 Reward: 2043.251
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 864.131
# ---------------------------------------
# Total T: 210097 Episode Num: 3052 Episode T: 1000 Reward: 2074.737
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 410.593
# ---------------------------------------
# Total T: 211097 Episode Num: 3053 Episode T: 1000 Reward: 2139.350
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1238.221
# ---------------------------------------
# Total T: 212097 Episode Num: 3054 Episode T: 1000 Reward: 2091.472
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1174.071
# ---------------------------------------
# Total T: 213097 Episode Num: 3055 Episode T: 1000 Reward: 2074.288
# Total T: 213169 Episode Num: 3056 Episode T: 72 Reward: 104.336
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 847.542
# ---------------------------------------
# Total T: 214169 Episode Num: 3057 Episode T: 1000 Reward: 2101.985
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1077.873
# ---------------------------------------
# Total T: 215169 Episode Num: 3058 Episode T: 1000 Reward: 2073.113
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1029.064
# ---------------------------------------
# Total T: 216169 Episode Num: 3059 Episode T: 1000 Reward: 2039.335
# Total T: 216240 Episode Num: 3060 Episode T: 71 Reward: 79.274
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1083.105
# ---------------------------------------
# Total T: 217240 Episode Num: 3061 Episode T: 1000 Reward: 2029.468
# Total T: 217396 Episode Num: 3062 Episode T: 156 Reward: 305.819
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 915.325
# ---------------------------------------
# Total T: 218396 Episode Num: 3063 Episode T: 1000 Reward: 2124.924
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1119.149
# ---------------------------------------
# Total T: 219396 Episode Num: 3064 Episode T: 1000 Reward: 2108.464
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 926.841
# ---------------------------------------
# Total T: 220396 Episode Num: 3065 Episode T: 1000 Reward: 2095.903
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1080.644
# ---------------------------------------
# Total T: 221396 Episode Num: 3066 Episode T: 1000 Reward: 2081.088
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1121.210
# ---------------------------------------
# Total T: 222396 Episode Num: 3067 Episode T: 1000 Reward: 2005.825
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1119.740
# ---------------------------------------
# Total T: 223396 Episode Num: 3068 Episode T: 1000 Reward: 2109.424
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1067.429
# ---------------------------------------
# Total T: 224396 Episode Num: 3069 Episode T: 1000 Reward: 2126.388
# Total T: 224428 Episode Num: 3070 Episode T: 32 Reward: 11.738
# Total T: 224465 Episode Num: 3071 Episode T: 37 Reward: 33.244
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1268.589
# ---------------------------------------
# Total T: 225465 Episode Num: 3072 Episode T: 1000 Reward: 2137.865
# Total T: 225528 Episode Num: 3073 Episode T: 63 Reward: 88.309
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1109.004
# ---------------------------------------
# Total T: 226528 Episode Num: 3074 Episode T: 1000 Reward: 2149.091
# Total T: 226621 Episode Num: 3075 Episode T: 93 Reward: 189.714
# Total T: 226698 Episode Num: 3076 Episode T: 77 Reward: 116.892
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1289.920
# ---------------------------------------
# Total T: 227698 Episode Num: 3077 Episode T: 1000 Reward: 2048.835
# Total T: 227775 Episode Num: 3078 Episode T: 77 Reward: 105.829
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 283.150
# ---------------------------------------
# Total T: 228775 Episode Num: 3079 Episode T: 1000 Reward: 1961.551
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1258.674
# ---------------------------------------
# Total T: 229775 Episode Num: 3080 Episode T: 1000 Reward: 2009.450
# Total T: 229852 Episode Num: 3081 Episode T: 77 Reward: 44.999
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1271.311
# ---------------------------------------
# Total T: 230852 Episode Num: 3082 Episode T: 1000 Reward: 2170.157
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 142.647
# ---------------------------------------
# Total T: 231852 Episode Num: 3083 Episode T: 1000 Reward: 2079.170
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 270.885
# ---------------------------------------
# Total T: 232852 Episode Num: 3084 Episode T: 1000 Reward: 2093.278
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1102.420
# ---------------------------------------
# Total T: 233852 Episode Num: 3085 Episode T: 1000 Reward: 2077.487
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1266.390
# ---------------------------------------
# Total T: 234152 Episode Num: 3086 Episode T: 300 Reward: 612.240
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1231.515
# ---------------------------------------
# Total T: 235152 Episode Num: 3087 Episode T: 1000 Reward: 2135.153
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1050.743
# ---------------------------------------
# Total T: 236152 Episode Num: 3088 Episode T: 1000 Reward: 2087.324
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1203.111
# ---------------------------------------
# Total T: 237152 Episode Num: 3089 Episode T: 1000 Reward: 2134.668
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1102.247
# ---------------------------------------
# Total T: 238152 Episode Num: 3090 Episode T: 1000 Reward: 2119.859
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1313.704
# ---------------------------------------
# Total T: 239152 Episode Num: 3091 Episode T: 1000 Reward: 2134.984
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1085.265
# ---------------------------------------
# Total T: 240152 Episode Num: 3092 Episode T: 1000 Reward: 2174.825
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1282.176
# ---------------------------------------
# Total T: 241152 Episode Num: 3093 Episode T: 1000 Reward: 2155.306
# Total T: 241270 Episode Num: 3094 Episode T: 118 Reward: 136.976
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1103.486
# ---------------------------------------
# Total T: 242270 Episode Num: 3095 Episode T: 1000 Reward: 2174.017
# Total T: 242743 Episode Num: 3096 Episode T: 473 Reward: 1017.806
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1049.637
# ---------------------------------------
# Total T: 243743 Episode Num: 3097 Episode T: 1000 Reward: 2054.136
# Total T: 243792 Episode Num: 3098 Episode T: 49 Reward: 42.499
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1276.762
# ---------------------------------------
# Total T: 244792 Episode Num: 3099 Episode T: 1000 Reward: 2121.325
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1123.700
# ---------------------------------------
# Total T: 245792 Episode Num: 3100 Episode T: 1000 Reward: 2141.918
# Total T: 245799 Episode Num: 3101 Episode T: 7 Reward: 3.422
# Total T: 245828 Episode Num: 3102 Episode T: 29 Reward: 29.740
# Total T: 245923 Episode Num: 3103 Episode T: 95 Reward: 143.724
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1222.806
# ---------------------------------------
# Total T: 246923 Episode Num: 3104 Episode T: 1000 Reward: 2116.113
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1289.371
# ---------------------------------------
# Total T: 247923 Episode Num: 3105 Episode T: 1000 Reward: 2151.561
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1295.770
# ---------------------------------------
# Total T: 248923 Episode Num: 3106 Episode T: 1000 Reward: 2064.914
# Total T: 248926 Episode Num: 3107 Episode T: 3 Reward: -1.505
# WalkerBase::__init__
# ---------------------------------------
# Evaluation over 10 episodes: 1136.651
# ---------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e3a720bd6fcc> in <module>()
# ----> 1 eval = train_agent(TD3, 'HopperMuJoCoEnv-v0')
#
# <ipython-input-3-683b1b5a1a69> in train_agent(agent_func, env_name, max_steps, max_step_before_learning)
#      67         # Train agent after collecting sufficient data
#      68         if t >= max_step_before_learning:
# ---> 69             policy.train(replay_buffer, 256)
#      70
#      71         if done:
#
# <ipython-input-2-b49f555eb895> in train(self, replay_buffer, batch_size)
#     172                 self.critic_optimizer.zero_grad()
#     173                 critic_loss.backward()
# --> 174                 self.critic_optimizer.step()
#     175
#     176                 # Delayed policy updates
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/adam.py in step(self, closure)
#     116                    lr=group['lr'],
#     117                    weight_decay=group['weight_decay'],
# --> 118                    eps=group['eps'])
#     119         return loss
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/_functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#      84
#      85         # Decay the first and second moment running average coefficient
# ---> 86         exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
#      87         exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
#      88         if amsgrad:
#
# KeyboardInterrupt:

# %% [markdown]
# # Training Function

# %%
from tqdm import trange
import gym
import pybulletgym

def mini_batch_rl(agent_func, 
                env_name, # this should be an env object
                runs=1,
                max_steps=int(1e6),
                max_path_length=1000,
                max_step_before_learning=10000
                ):
    returns_timing = []
    returns_value = []
    agents = []
    env = gym.make(env_name)
    state_dim = env.observation_space.shape[0]
    action_dim = env.action_space.shape[0]
    max_action = float(env.action_space.high[0])
    
    for run in trange(runs, desc='runs'):
        env.seed(run + 100)
        total_steps = 0
        done = True
        # each element in returns array should be of shape [episodic_return, steps]
        # if an episode is not over, episodic_return is 0
        rewards = []
        episodic_return = 0
        agent = agent_func(state_dim=state_dim,
                            action_dim=action_dim,
                            max_action=max_action,
                            max_step_before_learning=max_step_before_learning,
        )
        
        path_length=0

        while total_steps < max_steps:
            if done or path_length >= max_path_length:
                print(f'Steps : {total_steps}, Episodic_return : {episodic_return}')
                state = env.reset()
                done = False
                rewards.append([total_steps, episodic_return])
                episodic_return = 0
                path_length = 0

            path_length += 1
            total_steps += 1
            action = agent.select_action(state)
            next_state, reward, done, info = env.step(action)
            agent.train(state, action, next_state, reward, done)
            episodic_return += reward
        
        returns_timing.append(rewards[:, 0])
        returns_timing.append(rewards[:, 1])
        agents.append(agents)

        filename = f'./state_dict/{agent_func.__name__}-{env_name}-{random_seed}.pt'
        torch.save(agent.state_dict(), filename)
    
    return agents, returns_timing, returns_value

# %%
agents, t, r = mini_batch_rl(agent_func=TD3,
                           env_name='HopperMuJoCoEnv-v0')
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# runs:   0%|          | 0/1 [00:00<?, ?it/s]
# WalkerBase::__init__
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-439c3425de02> in <module>()
#       1 agents, t, r = mini_batch_rl(agent_func=TD3,
# ----> 2                            env_name='HopperMuJoCoEnv-v0')
#
# <ipython-input-14-ecdd89f45a2d> in mini_batch_rl(agent_func, env_name, runs, max_steps, max_path_length, max_step_before_learning)
#      29                             action_dim=action_dim,
#      30                             max_action=max_action,
# ---> 31                             max_step_before_learning=max_step_before_learning,
#      32         )
#      33
#
# TypeError: __init__() got an unexpected keyword argument 'max_step_before_learning'
